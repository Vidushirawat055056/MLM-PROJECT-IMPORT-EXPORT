# %% [markdown]
# # Import Export Data Analysis using Python
# ---

# %% [markdown]
# ## PROJECT CONTENTS:
#
# This project contains a detailed dataset and analysis of international trade transactions, providing extensive information on both imports and exports. Designed for use in business analytics, economic research, and financial modeling, it offers a broad view of trade activities with numerous attributes that capture various dimensions of each transaction.
#
# 1. Project Information
# 2. Description of Data
# 3. Data Sampling
# 4. Project Objectives | Problem Statements
# 5. Analysis of Data
# 6. Observations | Findings
# 7. Managerial Insights | Recommendations
#
# ---

# %% [markdown]
# ## A. Project Information
# * Title: Data Exploration with Python using Pandas & Numpy Libraries
# * Students : **Sejal Raj (055041) , Vidushi Rawat (055056)**
# * Group Number: 9
#
# ---

# %% [markdown]
# ## B. Description of Data
#
#  Data Source: [Dataset link]("https://drive.google.com/file/d/1vF0tDlasSDjl-3eKy7YCKxeSV_-te7zu/view?usp=sharing")
#
#  ***A live link is used in the dataset***

# %% [markdown]
# ### Data Columns Description:
#
# 1. Transaction_ID: Unique identifier for each trade transaction.
# 2. Country: Country of origin or destination for the trade.
# 3. Product: Product being traded.
# 4. Import_Export: Indicates whether the transaction is an import or export.
# 5. Quantity: Amount of the product traded.
# 6. Value: Monetary value of the product in USD.
# 7. Date: Date of the transaction.
# 8. Category: Category of the product (e.g., Electronics, Clothing, Machinery).
# 9. Port: Port of entry or departure.
# 10. Customs_Code: Customs or HS code for product classification.
# 11. Weight: Weight of the product in kilograms.
# 12. Shipping_Method: Method used for shipping (e.g., Air, Sea, Land).
# 13. Supplier: Name of the supplier or manufacturer.
# 14. Customer: Name of the customer or recipient.
# 15. Invoice_Number: Unique invoice number for the transaction.
# 16. Payment_Terms: Terms of payment (e.g., Net 30, Net 60, Cash on Delivery).

# %% [markdown]
# Data Type: Since the dataset contains multiple entities (countries) and records data over time, this is an example of **Panel Data** (also called longitudinal data)

# %% [markdown]
# ### Data Variables
# As observed, the dataset contains:
# 1. **All** non-null Variables
# 2. Numbers:
#     1. Interger Variables: **3**  (*Quantity, Customs_Code, Invoice_Number*)
#     2. Float (Decimal) Variables: **2**  (*Value, Weight*)
# 3. Text: **9**  (*Country, Product, Import_Export, Category, Port, Shipping_Method, Supplier, Customer, Payment_Terms*)
# 4. DateTime: **1** (*Date*)
#
# ---

# %% [markdown]
# ## C. Data Sampling
#
# From the Dataset containing 15,000 values, a sample of 5001 entries was taken. The dataset sample (now refered as my_sample) was taken into account for further exploration. To match with the project objectives, a new column was added to the sample dataset called **Total Value** which represented the product of value of the product and it's quantity Imported/Exported.

# %% [markdown]
# ### Data Variables
# My_sample dataset consists of follwing Nominal, Ordinal and Non-Categorical Data as follows:
# 1. Index_variables are 'Transaction_ID' and 'Invoice_Number'
# 2. Categorical Variables:
#     - Nominal_Variables are Country, Product, Import_Export, Category, Port, Shipping_Method, Supplier, Customs_Code and Customer
#     - Ordinal_variable is Payment_Terms
# 3. Non_Categorical_Variables are Quantity, Value and Weight
#
# ---

# %% [markdown]
# ### About the Dataset
#
# This dataset provides detailed information on international trade transactions, capturing both import and export activities. It includes comprehensive data on various aspects of trade, making it a valuable resource for business analysis, economic research, and financial modeling.
# The Dataset used in this project is a stored in a google drive which can be viewed by anyone.
#
# Data Format: The dataset is provided in CSV format, making it easy to load into data analysis tools and frameworks.
#
# Additional Notes:
# The dataset consists of 15,000 rows and the sample taken consits of 5001 rows, ensuring a substantial sample size for meaningful analysis.
# Data is generated with realistic variability, simulating actual trade transactions.

# %% [markdown]
# ## D. Project Objectives
#
# Pefrorm Unsupervised Machine Learning, Segmentation of Dataset using Unsupervised Machine Learning Clustering Algorithms, Identification of appropriate number of Segments or Clusters and Determination of Segment or Cluster Characteristics
#
# ---

# %% [markdown]
# ## E. Exploratory Data Analysis
#
# ### E.1. Data Preprocessing:
#
# - The data has no missing data present, hence no missin data treatment was performed.
# - For Encoding, Ordinal Encoder was used
# - For Scaling, Min-Max Scaler was used
#
# ### E.2. Descriptive Statistics
# Primarily the data was split into Categorical and Non-Categorical variables for Analysis. The analysis carried forward was as follows:
# - Non-Categorical Variables:
#     1. Measures of Central Tendency {Minimum | Maximum | Mean | Median | Mode | Percentile
#     2. Measures of Dispersion {Range | Standard Deviation | Skewness | Kurtosis | Correlation (Matrix) }
#     3. Composite Measure {Coefficient of Variation | Confidence Interval}
#
# - Categorical Variables:
#
#     1. Count | Frequency | Proportion | Minimum | Maximum | Mode | Rank
#
# ### E.3 Data Visualisation
#
# Various Subplots were used such as Bar, Heatmaps, Histograms and Co-relation Matrices
#
# ### E.4 Inferential Statistics
#
# - Categorical Variable [Nominal | Ordinal]
#   - Test of Homogeneity {Chi-sq}
#
# - Non-Categorical Variable
#   - Test of Normality {Shapiro-Wilk | Kolmogorov-Smirnov | Anderson-Darling | Jarque-Bera}
#   - Test of Correlation {t}
#
# ### E.5 Machine Learning Models
#
# 1. Dimensity Reduction: Records
# Clustering : K-Means (KM) | DBSCAN | BIRCH
#
# 2. Dimensity Reduction: Variables
# Principal Component Analysis
#
# ### E.6. Model Performance Metrics
#
# 1. Silhouette Coefficient | Davies-Bouldin Index to evaluate the model performance
#
# 2. Model Run Statistics
#   - Time Taken
#   - Memory Used
#
# ### E.7. Diagnostics
#
# - Clustering: Cluster Characteristics Nature of each Cluster (Homogeneity) | Difference between Clusters (Heterogeneity)
#
# ---

# %% [markdown]
# # F. Observations
#
# ## F.1. Nature of Data
#
# - The data has no missing data present, hence no missin data treatment was performed.
# - For Encoding, Ordinal Encoder was used
# - For Scaling, Min-Max Scaler was used
# - Symmetry: Both Quantity and Value show a relatively symmetric distribution, with their mean and median being close.
# - Variability: There is considerable variability in all three variables, as indicated by the standard deviations and the range between minimum and maximum values.
# - Skewness: Although not directly visible, given that the minimum values are much lower and the maximum values are quite high, these variables could be slightly positively skewed, with a few higher values pulling the mean above the median.
# - Mode values are lower than the mean and median for Value and Weight, which could indicate some common small transactions.
# - Range values confirm that the data has a very wide spread, indicating diverse transaction sizes.
# - Symmetry: All three variables have very low skewness, indicating their distributions are quite symmetric.
# - Flat Distributions: The negative kurtosis values for all three variables suggest that the distributions are flatter than normal, with fewer outliers.
# - Chi-square statistic: 4.21, P-value: 0.37, Degrees of freedom: 4
# - The normality tests for all variables (Quantity, Value, Weight, and Total_Value) reject the null hypothesis, indicating that the data for these variables does not follow a normal distribution.
# - The T-tests show significant correlations between Quantity and Total_Value, Value and Total_Value, and Weight and Total_Value, all with very low p-values (0.0).
# - There is no significant correlation between Quantity and Value, Quantity and Weight, or Value and Weight, as their p-values are greater than 0.05.
#
# ## F.2. Unsupervised Machine Learning: Clustering
#
# 1. Identification of Appropriate Clustering Model:
#   - KMeans & Birch: These methods perform well when the desired number of clusters is 2-3, which is appropriate in our case.
#   - DBSCAN: This method is better for identifying clusters in the data; however, the silhouette and Davies-Bouldin scores suggest that the clusters are not very distinct.
# 2. Determination of Appropriate Number of Clusters:
#   - KMeans: The optimal number of clusters is determined to be 2, based on the highest silhouette score and lowest Davies-Bouldin score.
#   - DBSCAN: Even after tuning of hyperparameters (eps and min_samples) to find the best clustering configuration, no configuration was identified.
#   - Birch: The optimal number of clusters is likely 2 or 3, similar to KMeans. The analysis was done till 6 clusters.
# 3. Discovery of Niche Clusters:
#   - Niche clusters were not identified in this analysis.
# 4. Distinguishing Features of Each Cluster:
#   - KMeans: Clusters are distinguished based on Import_Export and Total_Value. For instance, clusters may represent high-value exports or low-value imports. Cluster centroids provide insights into average trade flow and transaction value.
#   - DBSCAN: Clusters represent dense regions of similar trade flows and transaction values, while noise points (-1) are isolated, unique transactions. Key features include the density of imports/exports and transaction value.
#   - Birch: Birch clusters are hierarchically grouped based on Import_Export and Total_Value, representing distinct transaction patterns. Clusters reveal broad trends, such as variations in trade flow or transaction value.
#
#
# ## F.3. Detailed Observations for K-Means Clustering based on it's SS Score and DB Score:
#
# 1. Silhouette Coefficient
#
#   - We evaluated using K-means the Silhouette Score for K=2 to K=6. The results indicate that the optimal number of clusters is K=2, achieving the highest Silhouette Score of 0.7701, suggesting that the data naturally divides into two distinct groups. While K=3 provides a slightly lower score of 0.7108, it still represents well-defined clusters and could be considered for more granular segmentation. Clustering with K=4 or more resulted in lower scores (<0.6549), indicating overlapping or poorly defined clusters. Based on this analysis, we recommend using K=2 as the primary clustering solution, with K=3 as an alternative depending on the business context.
#
# 2. Davies-Bouldin Score / Index
#
#   - The Davies-Bouldin Score (DB) was used to evaluate clustering quality for K=2 to K=6. The analysis shows that the lowest DB Score of 0.3637 was achieved for K=2, indicating the best clustering quality with compact and well-separated clusters. For K=3, the DB Score increases slightly to 0.4397, suggesting slightly lower-quality clusters but still acceptable for more detailed segmentation. For K=4 and higher, the DB Score exceeds 0.5, indicating that clustering quality declines as the clusters become less distinct and compact. Based on these results, K=2 is recommended as the optimal clustering solution, with K=3 as a potential alternative if finer segmentation is required.
#
# **Hence we would be proceeding with K-Means Clusturing and k=2 clusters for the project as it has best model run statistics**

# %% [markdown]
# #G. Managerial Insights
#
# ##G.1 Data Preprocessing
#
# ##G.1.1 Missing Data Treatment
#
# The dataset contains no missing values, eliminating the need for any imputation techniques.
#
# ##G.1.2 Categorical Data Encoding
#
# Ordinal Encoding: Applied to ordinal variables like Payment_Terms to preserve their inherent order.
# One-Hot Encoding: Recommended for nominal variables such as Country, Product, Category, Port, and Shipping_Method for downstream tasks requiring one-hot encoded features. Ordinal Encoding was used for this analysis, but other methods can be considered depending on the specific use case.
# ##G.1.3 Numerical Data Treatment
#
# Scaling: Min-Max Scaling was applied to normalize variables like Quantity, Value, and Weight to a [0, 1] range, improving model performance and interpretability.
# Outlier Treatment: Outliers in numerical variables like Value and Total_Value were retained as they likely represent significant business transactions and should not be arbitrarily removed.
# ##G.1.4 Data Splitting
#
# An 80:20 split was used to divide the data into training and testing sets. Random sampling without replacement was employed, as clustering algorithms are generally less sensitive to data order compared to supervised learning models.
#
# ##G.2 Unsupervised Machine Learning: Clustering
#
# ##G.2.1 Segmentation Purpose
#
# The primary objective of segmentation is to identify distinct groups of trade transactions based on factors such as trade flow (import/export), transaction size (Total_Value), and other relevant attributes. This segmentation will enable a deeper understanding of customer/supplier behaviors and facilitate the optimization of logistics strategies.
#
# ##G.2.2 Clustering Model Insights
#
# K-Means Clustering:
#
# Cluster Characteristics:
# Cluster 1: Characterized by high Total_Value transactions, primarily associated with export activities.
# Cluster 2: Comprises transactions with lower Total_Value, encompassing both import and export activities.
# Cluster Interpretation:
# Cluster 1: "High-Value Exporters" - Represents transactions with significant economic value and a focus on export operations.
# Cluster 2: "Low-Value Transactions" - Represents a broader range of transactions with lower economic value, including both import and export activities.
# Business Implications:
# Cluster 1: Prioritize targeted marketing and offer premium logistics services to this high-value segment.
# Cluster 2: Focus on cost-optimization strategies for smaller transactions, such as streamlined processes and efficient logistics solutions.
# DBSCAN Clustering:
#
# Cluster Characteristics: Identifies dense regions of trade activity but also includes noise points representing unique transactions.
# Model Limitations: The model produced less distinct clusters with lower Silhouette and Davies-Bouldin scores, making it less suitable for general segmentation purposes.
# Potential Use Case: DBSCAN may be more suitable for anomaly detection or identifying specific patterns within the data.
# Birch Clustering:
#
# Cluster Characteristics:
# Cluster 1: Represents large transactions with high trade values.
# Cluster 2: Characterizes transactions with moderate trade values.
# Cluster 3: Represents smaller transactions with low trade values.
# Cluster Interpretation:
# Cluster 1: "Premium Trade Segment" - Characterized by high-value transactions.
# Cluster 2: "Mid-Tier Trade Segment" - Represents transactions with moderate value.
# Cluster 3: "Budget Trade Segment" - Represents transactions with lower values.
# Business Implications:
# Cluster 1: Focus on high-value customer relationships, providing tailored services and premium offerings.
# Cluster 3: Implement cost-efficiency measures for smaller transactions to optimize resource allocation.
# ##G.3 Recommended Clustering Model
#
# K-Means with K=2 is recommended as the most effective model for segmenting the data. It provides the most distinct clusters with optimal Silhouette (0.7731) and Davies-Bouldin (0.3637) scores, indicating well-separated and cohesive clusters.
#
# Alternatively, K-Means with K=3 can be considered if more granular segmentation is required to meet specific business objectives.

# %% [markdown]
# --- End of Report ---

# %% [markdown]
# ## Project Information

# %%
# Import Relevant Python Libraries

import io
import requests
# !pip install requests

import pandas as pd
import statsmodels.formula.api as sm
from scipy.stats import chi2_contingency
from scipy.stats import shapiro, kstest, anderson, jarque_bera
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, DBSCAN, Birch
from scipy.cluster.hierarchy import dendrogram, linkage

import statsmodels.stats.descriptivestats as dstats
import numpy as np  # For Data Manipulation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder  # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.impute import SimpleImputer, KNNImputer  # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler  # For Rescaling Data
from sklearn.model_selection import train_test_split  # For Splitting Data into Training & Testing Sets
import matplotlib.pyplot as plt
import seaborn as sns  # For Data Visualization
import scipy.cluster.hierarchy as sch  # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus  # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score as sscore, davies_bouldin_score as dbscore  # For Clustering Model Evaluation
import statsmodels.api as sm
from sklearn import metrics
import scipy.stats as stats
import statsmodels.stats.multicomp as multi
import warnings
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score, davies_bouldin_scor
warnings.filterwarnings('ignore')

# %%
#2. Load the Data.
import pandas as pd
import requests
from io import StringIO

# Replace with your actual file ID
file_id = '1EuiZKcp0qgaoLF-j_-Sup55-dWID86cg'

# Construct the URL
url = f'https://drive.google.com/uc?id={file_id}'

# Fetch the data using requests
response = requests.get(url)
response.raise_for_status()  # Raise an exception for bad responses

vr56_df = pd.read_csv(StringIO(response.text))

# Display the first few rows of the DataFrame
vr56_df.head(2)
# Out:
#                          Transaction_ID   Country    Product Import_Export  \
# 0  e3e70682-c209-4cac-a29f-6fbed82c07cd  Colombia   describe        Export
# 1  f728b4fa-4248-4e3a-8a5d-2f346baa9455     Chile  president        Export
#
#    Quantity    Value        Date   Category        Port  Customs_Code  \
# 0      1979  9506.57  07-12-2023  Machinery  Robertbury        620537
# 1      5763  7100.91  04-04-2023   Clothing    Shahport        927600
#
#     Weight Shipping_Method                         Supplier       Customer  \
# 0  4248.65             Air  Garrison, Hubbard and Hendricks      Seth Hall
# 1  4340.81             Air                        Webb-Mack  Kimberly Ryan
#
#    Invoice_Number     Payment_Terms
# 0        21000294  Cash on Delivery
# 1        88738432           Prepaid

# %%
#Adding a total Value Variable

vr56_df['Total_Value'] = round(vr56_df['Value']*vr56_df['Quantity'],0)
vr56_df.head(3)
# Out:
#                          Transaction_ID   Country    Product Import_Export  \
# 0  e3e70682-c209-4cac-a29f-6fbed82c07cd  Colombia   describe        Export
# 1  f728b4fa-4248-4e3a-8a5d-2f346baa9455     Chile  president        Export
# 2  eb1167b3-67a9-4378-bc65-c1e582e2e662    Turkey        far        Import
#
#    Quantity    Value        Date     Category              Port  Customs_Code  \
# 0      1979  9506.57  07-12-2023    Machinery        Robertbury        620537
# 1      5763  7100.91  04-04-2023     Clothing          Shahport        927600
# 2      5740  2450.34  21-08-2024  Electronics  South Joshuatown        299258
#
#     Weight Shipping_Method                         Supplier       Customer  \
# 0  4248.65             Air  Garrison, Hubbard and Hendricks      Seth Hall
# 1  4340.81             Air                        Webb-Mack  Kimberly Ryan
# 2  4538.41             Air        Mendez, Jones and Johnson     Ryan Silva
#
# ...

# %%
# Data Dimensions
print("The dimensions of the data is: ",vr56_df.shape)
# Out:
# The dimensions of the data is:  (15000, 17)

# %%
# Data Variable Type
vr56_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   15000 non-null  object
#  1   Country          15000 non-null  object
#  2   Product          15000 non-null  object
#  3   Import_Export    15000 non-null  object
#  4   Quantity         15000 non-null  int64
#  5   Value            15000 non-null  float64
#  6   Date             15000 non-null  object
#  7   Category         15000 non-null  object
#  8   Port             15000 non-null  object
#  9   Customs_Code     15000 non-null  int64
#  10  Weight           15000 non-null  float64
#  11  Shipping_Method  15000 non-null  object
#  12  Supplier         15000 non-null  object
#  13  Customer         15000 non-null  object
#  14  Invoice_Number   15000 non-null  int64
#  15  Payment_Terms    15000 non-null  object
# ...

# %%
# Columns in the dataset

vr56_variables=list(vr56_df.columns)
print("The Variables are:", vr56_variables)
# Out:
# The Variables are: ['Transaction_ID', 'Country', 'Product', 'Import_Export', 'Quantity', 'Value', 'Date', 'Category', 'Port', 'Customs_Code', 'Weight', 'Shipping_Method', 'Supplier', 'Customer', 'Invoice_Number', 'Payment_Terms', 'Total_Value']

# %%
# Bifurcating the Variables into Index, Categorical (Nominal, Ordinal) and Non-Categorical Variables

vr56_index_vars=['Transaction_ID','Invoice_Number']
vr56_nominal_vars=[ 'Country','Product','Import_Export','Category','Port','Shipping_Method','Supplier','Customer','Customs_Code']
vr56_ordinal_vars=['Payment_Terms']

vr56_cat_vars=vr56_nominal_vars+vr56_ordinal_vars
vr56_non_cat_vars=['Quantity','Value','Weight','Total_Value']

# %%
# Data Types

print("Data Types:")
print(vr56_df.dtypes)
# Out:
# Data Types:
# Transaction_ID      object
# Country             object
# Product             object
# Import_Export       object
# Quantity             int64
# Value              float64
# Date                object
# Category            object
# Port                object
# Customs_Code         int64
# Weight             float64
# Shipping_Method     object
# Supplier            object
# Customer            object
# Invoice_Number       int64
# Payment_Terms       object
# Total_Value        float64
# dtype: object

# %% [markdown]
# ## Data Sampling

# %%
# A Unique Sample of 5001 Records
vr56_sample = pd.DataFrame.sample(vr56_df, n=5001, random_state= 4156 ,ignore_index=False)

# %%
# Displaying the Dimensions of Sample Data.
vr56_sample.shape
# Out:
# (5001, 17)

# %% [markdown]
# ## Data Preprocessing

# %%
vr56_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5001 entries, 620 to 12793
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   5001 non-null   object
#  1   Country          5001 non-null   object
#  2   Product          5001 non-null   object
#  3   Import_Export    5001 non-null   object
#  4   Quantity         5001 non-null   int64
#  5   Value            5001 non-null   float64
#  6   Date             5001 non-null   object
#  7   Category         5001 non-null   object
#  8   Port             5001 non-null   object
#  9   Customs_Code     5001 non-null   int64
#  10  Weight           5001 non-null   float64
#  11  Shipping_Method  5001 non-null   object
#  12  Supplier         5001 non-null   object
#  13  Customer         5001 non-null   object
#  14  Invoice_Number   5001 non-null   int64
#  15  Payment_Terms    5001 non-null   object
# ...

# %%
# Check for missing values

vr56_sample.isnull().sum(axis=1)
# Out:
# 620      0
# 288      0
# 3681     0
# 14061    0
# 5116     0
#         ..
# 9397     0
# 2324     0
# 10823    0
# 8276     0
# 12793    0
# Length: 5001, dtype: int64

# %% [markdown]
# ### This shows that our code has no missing data, hence we would be skipping the missing data treatment

# %%
# Encoding

vr56_oe = OrdinalEncoder()
vr56_categorical_cols = vr56_sample[vr56_cat_vars]
vr56_oe_fit = vr56_oe.fit_transform(vr56_categorical_cols)
vr56_encoded = pd.DataFrame(vr56_oe_fit, columns=vr56_cat_vars)
vr56_encoded.head()
# Out:
#    Country  Product  Import_Export  Category    Port  Shipping_Method  \
# 0     79.0    757.0            1.0       4.0  2711.0              1.0
# 1    144.0    321.0            0.0       2.0   746.0              2.0
# 2     96.0    356.0            0.0       0.0    76.0              2.0
# 3    122.0     56.0            1.0       0.0   894.0              1.0
# 4     72.0    732.0            0.0       4.0  3029.0              2.0
#
#    Supplier  Customer  Customs_Code  Payment_Terms
# 0    3962.0    2347.0         926.0            3.0
# 1    3165.0     681.0        1592.0            0.0
# 2     413.0    4579.0        1589.0            3.0
# 3    1826.0    3235.0        1940.0            2.0
# 4    1853.0    2593.0        2172.0            2.0

# %% [markdown]
# encoding : The data highlights key variables in international trade, such as shipping methods, payment terms, and customer-supplier dynamics. Notably, shipping preferences vary significantly by port, with certain categories relying heavily on specific methods. Payment terms and customs codes indicate diverse trade regulations and risk levels. Managers should focus on optimizing logistics strategies and tailoring payment terms to improve operational efficiency and customer satisfaction.

# %%
#Scaling

vr56_scaler = MinMaxScaler()
vr56_scaled_data = vr56_scaler.fit_transform(vr56_sample[vr56_non_cat_vars])
vr56_scaled = pd.DataFrame(vr56_scaled_data, columns=vr56_non_cat_vars)
vr56_scaled.head()
# Out:
#    Quantity     Value    Weight  Total_Value
# 0  0.138666  0.978151  0.593734     0.138117
# 1  0.902683  0.555721  0.558924     0.512679
# 2  0.686824  0.652104  0.814226     0.456605
# 3  0.894573  0.027183  0.350040     0.033669
# 4  0.968763  0.550880  0.228690     0.545477

# %% [markdown]
# scaling: The data reveals that while quantity and weight often align with value, there are inconsistencies in how these factors contribute to the total value. For example, higher quantities don't always translate into proportionally higher total values, suggesting potential inefficiencies or varying profit margins. Managers should analyze product-specific value contributions to refine pricing strategies and optimize inventory management.

# %%
# The pre-processed Dataset

vr56_processed = pd.concat([vr56_scaled, vr56_encoded], axis=1)
vr56_processed.head()

vr56_sample = vr56_processed
vr56_sample.head()
# Out:
#    Quantity     Value    Weight  Total_Value  Country  Product  Import_Export  \
# 0  0.138666  0.978151  0.593734     0.138117     79.0    757.0            1.0
# 1  0.902683  0.555721  0.558924     0.512679    144.0    321.0            0.0
# 2  0.686824  0.652104  0.814226     0.456605     96.0    356.0            0.0
# 3  0.894573  0.027183  0.350040     0.033669    122.0     56.0            1.0
# 4  0.968763  0.550880  0.228690     0.545477     72.0    732.0            0.0
#
#    Category    Port  Shipping_Method  Supplier  Customer  Customs_Code  \
# 0       4.0  2711.0              1.0    3962.0    2347.0         926.0
# 1       2.0   746.0              2.0    3165.0     681.0        1592.0
# 2       0.0    76.0              2.0     413.0    4579.0        1589.0
# 3       0.0   894.0              1.0    1826.0    3235.0        1940.0
# 4       4.0  3029.0              2.0    1853.0    2593.0        2172.0
#
#    Payment_Terms
# 0            3.0
# 1            0.0
# ...

# %% [markdown]
# The data shows that total value does not always align with quantity or weight, indicating potential inefficiencies or varying product pricing. Managers should focus on optimizing product value, shipping methods, and payment terms to improve cost-effectiveness and profitability.

# %% [markdown]
# ---

# %% [markdown]
# ## Descriptive Statistics

# %% [markdown]
# ### Non-Categorical Variables

# %%
vr56_sample[vr56_non_cat_vars].describe()
# Out:
#           Quantity        Value       Weight  Total_Value
# count  5001.000000  5001.000000  5001.000000  5001.000000
# mean      0.495741     0.501354     0.504676     0.254872
# std       0.286801     0.288894     0.291027     0.223364
# min       0.000000     0.000000     0.000000     0.000000
# 25%       0.247397     0.248225     0.251678     0.073351
# 50%       0.499299     0.505145     0.507268     0.190351
# 75%       0.742891     0.755226     0.759530     0.388132
# max       1.000000     1.000000     1.000000     1.000000

# %% [markdown]
# Observations:
#
# Distribution:
#
# All four variables (Quantity, Value, Weight, Total_Value) appear to be roughly symmetrically distributed.
# This is suggested by the close proximity of the mean and median values (50th percentile).
# The standard deviation is relatively small compared to the range, further supporting the idea of a relatively symmetric distribution.
# Range:
#
# All variables have a range of 1, indicating that their values fall between 0 and 1.
# Central Tendency:
#
# The mean values for all variables are close to , suggesting that the data is centered around the middle of the possible range.
# Relationship between variables:
#
# It's difficult to infer direct relationships between variables from this summary alone.
# The provided statistics (mean, std, min, max, percentiles) primarily describe the distribution of each variable individually.

# %%
def summarize_numerical(my_sample, variables):
    summary = {}

    for col in variables:
        if col in vr56_sample[vr56_non_cat_vars]:  # Check if the column exists in the DataFrame
            summary[col] = {
                'Mode': my_sample[col].mode()[0],
                'Range': my_sample[col].max() - my_sample[col].min(),
                'Skewness': my_sample[col].skew() ,
                'Kurtosis': my_sample[col].kurtosis()
            }
    return summary

# %%
summary_stats = summarize_numerical(vr56_sample,vr56_non_cat_vars)
summary_df = pd.DataFrame.from_dict(summary_stats, orient='index')
summary_df
# Out:
#                  Mode  Range  Skewness  Kurtosis
# Quantity     0.571085    1.0  0.003569 -1.191667
# Value        0.005195    1.0  0.005693 -1.201969
# Weight       0.016886    1.0 -0.003314 -1.221638
# Total_Value  0.018960    1.0  1.008554  0.263138

# %%
# Coefficient of Variation
def coefficient_of_variation(data):
    mean = data.mean()
    std = data.std()
    cv = (std / mean) * 100
    return cv

cv_results = {}

for col in vr56_non_cat_vars:
    cv_results[col] = coefficient_of_variation(vr56_sample[col])

# Display the results
print("Coefficient of Variation (%):")
for col, cv in cv_results.items():
    print(f"{col}: {cv:.2f}%")
# Out:
# Coefficient of Variation (%):
# Quantity: 57.85%
# Value: 57.62%
# Weight: 57.67%
# Total_Value: 87.64%

# %%
# Confidence Interval for the Mean
def confidence_interval(data, confidence=0.95):
    mean = data.mean()
    std = data.std()
    n = len(data)
    z = stats.norm.ppf(1 - (1 - confidence) / 2)  # z-score for 95% CI
    margin_of_error = z * (std / np.sqrt(n))
    lower_bound = mean - margin_of_error
    upper_bound = mean + margin_of_error
    return (lower_bound, upper_bound)

ci_results = {}
for col in vr56_non_cat_vars:
    ci_results[col] = confidence_interval(vr56_sample[col])


print("\nConfidence Intervals (95%):")
for col, ci in ci_results.items():
    print(f"{col}: {ci[0]:.2f} to {ci[1]:.2f}")
# Out:
# Confidence Intervals (95%):
# Quantity: 0.49 to 0.50
# Value: 0.49 to 0.51
# Weight: 0.50 to 0.51
# Total_Value: 0.25 to 0.26

# %% [markdown]
# 1. Moderate Relative Variability: All Non-Categorical variables exhibit a moderate degree of relative variability, with CV values **above 55%**. This indicates that while there is variation in the data, it’s not extreme.
# 2. Confidence in the Mean: The narrow confidence intervals suggest that, despite the variability, the estimates for the mean of each variable are fairly precise.
# 3. Weight's Higher Variability: While the confidence interval for weight is wider than those for quantity and value, the overall variability in weight reflects that the traded goods may have a more diverse range of weights compared to their quantities or values.

# %%
correlation_data = vr56_sample[vr56_non_cat_vars]
correlation_matrix = correlation_data.corr()
print("Correlation Matrix:")
correlation_matrix
# Out:
# Correlation Matrix:
#              Quantity     Value    Weight  Total_Value
# Quantity     1.000000  0.002637  0.004161     0.664979
# Value        0.002637  1.000000 -0.007834     0.648175
# Weight       0.004161 -0.007834  1.000000    -0.000118
# Total_Value  0.664979  0.648175 -0.000118     1.000000

# %%
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# Observation
#
# - *Strong Correlation*:
#   - Total_Value is strongly linked to Quantity and Value, likely because Total_Value = Quantity × Value.
#
# - *Weak Correlation*:
#   - Minimal relationship between Quantity, Value, and Weight.
#
# - *Analysis*:
#   - *Predictive Power*: Quantity and Value are key predictors for Total_Value; Weight has limited impact.
#   - *Pricing & Revenue*: Pricing strategies affect Total_Value through Quantity and Value.
#   - *Inventory Management*: Understanding the Quantity-Total_Value relationship helps optimize inventory.
#   - *Product Mix*: High-value products impact Total_Value more than low-value, high-quantity products.
#   - *Weight's Role*: Weight has little effect on Total_Value and profitability.

# %% [markdown]
# ### Categorical

# %%
# Categorical Data

def vr56_categorical_summary(df, cat_cols):
    summary = {}
    for col in cat_cols:
        if col in df.columns:
            summary[col] = {
                'Count': df[col].count(),
                'Minimum': df[col].min(),
                'Maximum': df[col].max(),
                'Mode': df[col].mode().iloc[0],
            }
    return summary

vr56_categorical_summaries = vr56_categorical_summary(vr56_sample, vr56_cat_vars)

for col, stats in vr56_categorical_summaries.items():
    print(f"Summary for {col}:")
    for stat_name, stat_value in stats.items():
        print(f"  {stat_name}: {stat_value}")
    print("-" * 20)  # separator
# Out:
# Summary for Country:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 242.0
#   Mode: 114.0
# --------------------
# Summary for Product:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 964.0
#   Mode: 177.0
# --------------------
# Summary for Import_Export:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 1.0
#   Mode: 0.0
# --------------------
# Summary for Category:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4.0
#   Mode: 0.0
# --------------------
# Summary for Port:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4271.0
#   Mode: 1664.0
# --------------------
# Summary for Shipping_Method:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 2.0
#   Mode: 2.0
# --------------------
# Summary for Supplier:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4567.0
#   Mode: 2015.0
# --------------------
# Summary for Customer:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4842.0
#   Mode: 3330.0
# --------------------
# Summary for Customs_Code:
#   Count: 5001
#   Minimum: 0.0
# ...

# %% [markdown]
# ### Data Visualisation

# %%
# Box plots for non-categorical variables

plt.figure(figsize=(15, 10))
for i, col in enumerate(vr56_non_cat_vars):
    plt.subplot(2, 3, i + 1)
    sns.boxplot(y=vr56_sample[col])
    plt.title(f'Box Plot of {col}')
plt.tight_layout()
plt.show()

# %%
# Histograms with KDE for distribution visualization
plt.figure(figsize=(15, 10))
for i, col in enumerate(vr56_non_cat_vars):
    plt.subplot(2, 3, i + 1)
    sns.histplot(vr56_sample[col], kde=True)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Inferential Statistics

# %%
#Test of Homogeneity {Chi-sq} on categorical data

vr56_contingency_table = pd.crosstab(vr56_sample['Import_Export'], vr56_sample['Category'])

# Perform the Chi-square test
chi2, p, dof, expected = chi2_contingency(vr56_contingency_table)

print(f"Chi-square statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of freedom: {dof}")
print("Expected frequencies:")
print(expected)

# Interpret the results
vr56_alpha = 0.05  # Significance level

if p < vr56_alpha:
    print("Reject the null hypothesis: There is a significant association between the two categorical variables.")
else:
    print("There is no significant association between the two categorical variables.")
# Out:
# Chi-square statistic: 4.218502174325903
# P-value: 0.3772416943205113
# Degrees of freedom: 4
# Expected frequencies:
# [[521.14377125 491.57888422 514.12837433 494.5854829  484.5634873 ]
#  [518.85622875 489.42111578 511.87162567 492.4145171  482.4365127 ]]
# There is no significant association between the two categorical variables.

# %%
# Test of Normality {Shapiro-Wilk | Kolmogorov-Smirnov | Anderson-Darling | Jarque-Bera

def normality_tests(data):

    vr56_results = {}

    # Shapiro-Wilk test
    shapiro_statistic, shapiro_pvalue = shapiro(data)
    vr56_results["Shapiro-Wilk"] = {"statistic": shapiro_statistic, "p-value": shapiro_pvalue}

    # Kolmogorov-Smirnov test (against a normal distribution)
    ks_statistic, ks_pvalue = kstest(data, 'norm')
    vr56_results["Kolmogorov-Smirnov"] = {"statistic": ks_statistic, "p-value": ks_pvalue}

    # Anderson-Darling test
    anderson_result = anderson(data)
    vr56_results["Anderson-Darling"] = {
        "statistic": anderson_result.statistic,
        "critical_values": anderson_result.critical_values,
        "significance_level": anderson_result.significance_level
    }

    # Jarque-Bera test
    jb_statistic, jb_pvalue = jarque_bera(data)
    vr56_results["Jarque-Bera"] = {"statistic": jb_statistic, "p-value": jb_pvalue}

    return vr56_results

# %%
from scipy import stats

# Test of Correlation (T-test)
def t_test_correlation(data1, data2):
    t_statistic, p_value = stats.ttest_ind(data1, data2)
    return {"t-statistic": t_statistic, "p-value": p_value}

for col in vr56_non_cat_vars:
    print(f"Normality tests for {col}:")
    normality_test_results = normality_tests(vr56_sample[col])
    for test_name, result in normality_test_results.items():
        print(f"  {test_name}: {result}")

    # Example of T-test
    if len(vr56_non_cat_vars) > 1:
        for i in range(len(vr56_non_cat_vars)):
            for j in range(i+1, len(vr56_non_cat_vars)):
                col1, col2 = vr56_non_cat_vars[i], vr56_non_cat_vars[j]
                t_test_result = t_test_correlation(vr56_sample[col1], vr56_sample[col2])
                print(f"T-test Correlation between {col1} and {col2}: {t_test_result}")
    print()
    print('*'*20)
    print()
# Out:
# Normality tests for Quantity:
#   Shapiro-Wilk: {'statistic': 0.9561271096923879, 'p-value': 2.3254167469765947e-36}
#   Kolmogorov-Smirnov: {'statistic': 0.5002793457802577, 'p-value': 0.0}
#   Anderson-Darling: {'statistic': 54.21452511748794, 'critical_values': array([0.576, 0.655, 0.786, 0.917, 1.091]), 'significance_level': array([15. , 10. ,  5. ,  2.5,  1. ])}
#   Jarque-Bera: {'statistic': 295.92182670212173, 'p-value': 5.5130482607076404e-65}
# T-test Correlation between Quantity and Value: {'t-statistic': -0.9750194252295252, 'p-value': 0.32957420914910907}
# T-test Correlation between Quantity and Weight: {'t-statistic': -1.5464243627911785, 'p-value': 0.12203375812319554}
# T-test Correlation between Quantity and Total_Value: {'t-statistic': 46.857662532177244, 'p-value': 0.0}
# T-test Correlation between Value and Weight: {'t-statistic': -0.5729608690073799, 'p-value': 0.5666840719315471}
# ...

# %% [markdown]
# # Unsupervised Machine Learning
#
# ## Dimensity Reduction: Records

# %% [markdown]
# ### K-Means Clustering

# %%
# Subset for cluster - Trade Flow

vr56_ds_subset = vr56_processed[['Import_Export','Total_Value']]
vr56_ds_subset

# Create K-Means Clusters
# ------------------------------------------

vr56_km_2cluster = kmclus(n_clusters=2, init='random', random_state=43)
vr56_km_2cluster_model = vr56_km_2cluster.fit_predict(vr56_ds_subset); vr56_km_2cluster_model

vr56_km_3cluster = kmclus(n_clusters=3, init='random', random_state=43)
vr56_km_3cluster_model = vr56_km_3cluster.fit_predict(vr56_ds_subset); vr56_km_3cluster_model

vr56_km_4cluster = kmclus(n_clusters=4, init='random', random_state=43)
vr56_km_4cluster_model = vr56_km_4cluster.fit_predict(vr56_ds_subset); vr56_km_4cluster_model

vr56_km_5cluster = kmclus(n_clusters=5, init='random', random_state=43)
vr56_km_5cluster_model = vr56_km_5cluster.fit_predict(vr56_ds_subset); vr56_km_5cluster_model

vr56_km_6cluster = kmclus(n_clusters=6, init='random', random_state=43)
vr56_km_6cluster_model = vr56_km_6cluster.fit_predict(vr56_ds_subset); vr56_km_6cluster_model
# Out:
# array([2, 3, 5, ..., 2, 0, 2], dtype=int32)

# %%
from sklearn.metrics import silhouette_score as sscore, davies_bouldin_score as dbscore

# Function to tune DBSCAN hyperparameters
def tune_dbscan(data, eps_values, min_samples_values):
    results = []
    for eps in eps_values:
        for min_samples in min_samples_values:
            dbscan = DBSCAN(eps=eps, min_samples=min_samples)
            labels = dbscan.fit_predict(data)

            # Ensure there are at least 2 clusters (excluding noise) to compute scores
            if len(set(labels)) > 1 and sum(labels == -1) < len(labels):
                try:
                    silhouette = sscore(data, labels)
                    davies_bouldin = dbscore(data, labels)
                except Exception as e:
                    # Handle cases where scores can't be computed
                    silhouette = None
                    davies_bouldin = None

                results.append({
                    "eps": eps,
                    "min_samples": min_samples,
                    "clusters": len(set(labels)) - (1 if -1 in labels else 0),
                    "noise_points": sum(labels == -1),
                    "silhouette_score": silhouette,
                    "davies_bouldin_score": davies_bouldin
                })
    # Return DataFrame only with valid results
    return pd.DataFrame(results)

# Example: Adjust ranges for eps and min_samples
eps_values = np.arange(0.1, 1.0, 0.1)  # Try values from 0.1 to 1.0
min_samples_values = range(2, 10)      # Try values from 2 to 10

# Run tuning function
vr56_dbscan_results = tune_dbscan(vr56_processed, eps_values, min_samples_values)

# %% [markdown]
# ## BIRCH Clustering

# %%
vr56_birch2 = Birch(n_clusters=2)
vr56_birch2_labels = vr56_birch2.fit_predict(vr56_processed)

vr56_birch3 = Birch(n_clusters=3)
vr56_birch3_labels = vr56_birch3.fit_predict(vr56_processed)

vr56_birch4 = Birch(n_clusters=4)
vr56_birch4_labels = vr56_birch4.fit_predict(vr56_processed)

vr56_birch5 = Birch(n_clusters=5)
vr56_birch5_labels = vr56_birch5.fit_predict(vr56_processed)

vr56_birch6 = Birch(n_clusters=6)
vr56_birch6_labels = vr56_birch6.fit_predict(vr56_processed)

# %% [markdown]
# ## Dimensity Reduction: Variables
#
# ### Principal Component Analysis

# %%
pca_records = PCA(n_components=2)  # Reduce to 2 dimensions for visualization
vr56_pca_records = pca_records.fit_transform(vr56_processed)
vr56_pca_records
# Out:
# array([[-1649.51218115,   136.1800315 ],
#        [-1129.69667415, -1534.61414434],
#        [ -514.68649796,  2298.26598797],
#        ...,
#        [ 1288.46611502,   192.31179399],
#        [-2058.59197262,   166.68450044],
#        [  323.7998986 ,  1020.83344811]])

# %%
plt.figure(figsize=(8, 6))
plt.scatter(vr56_pca_records[:, 0], vr56_pca_records[:, 1], alpha=0.5)
plt.title("PCA: Dimensionality Reduction on Records")
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.show()

# %% [markdown]
# # Model Performance Metrics

# %% [markdown]
# ## K-Means Clustering

# %%
# K-Means Clustering Model Evaluation [K=2 | K=3]

vr56_sscore_km_2cluster = sscore(vr56_ds_subset, vr56_km_2cluster_model); vr56_sscore_km_2cluster
vr56_dbscore_km_2cluster = dbscore(vr56_ds_subset, vr56_km_2cluster_model); vr56_dbscore_km_2cluster

vr56_sscore_km_3cluster = sscore(vr56_ds_subset, vr56_km_3cluster_model); vr56_sscore_km_3cluster
vr56_dbscore_km_3cluster = dbscore(vr56_ds_subset, vr56_km_3cluster_model); vr56_dbscore_km_3cluster

vr56_sscore_km_4cluster = sscore(vr56_ds_subset, vr56_km_4cluster_model); vr56_sscore_km_4cluster
vr56_dbscore_km_4cluster = dbscore(vr56_ds_subset, vr56_km_4cluster_model); vr56_dbscore_km_4cluster

vr56_sscore_km_5cluster = sscore(vr56_ds_subset, vr56_km_5cluster_model); vr56_sscore_km_5cluster
vr56_dbscore_km_5cluster = dbscore(vr56_ds_subset, vr56_km_5cluster_model); vr56_dbscore_km_5cluster

vr56_sscore_km_6cluster = sscore(vr56_ds_subset, vr56_km_6cluster_model); vr56_sscore_km_6cluster
vr56_dbscore_km_6cluster = dbscore(vr56_ds_subset, vr56_km_6cluster_model); vr56_dbscore_km_6cluster


vr56_sscores = [vr56_sscore_km_2cluster,vr56_sscore_km_3cluster,vr56_sscore_km_4cluster,vr56_sscore_km_5cluster,vr56_sscore_km_6cluster]
vr56_sscores
# Out:
# [0.7701417879683989,
#  0.710803491482226,
#  0.6549230485316412,
#  0.6288320479394612,
#  0.6023098137971248]

# %% [markdown]
# ### Clustering Analysis:
#
# Optimal Number of Clusters:
#
# - Based on the scores, K=2 is the optimal choice if the goal is to maximize cohesion and separation.
# - However, if K=3 aligns better with your business context or provides more meaningful segmentation, it is also a viable choice.
# Quality of Clusters:
#
# - A Silhouette Score of ~0.77 for K=3 indicates that the clusters are still reasonably well-separated and cohesive, though not as strong as with K=2.
# For K=4 to K=6, the scores drop below 0.65, suggesting less well-defined clusters and possible overlap between them.

# %%
vr56_dbscores = [vr56_dbscore_km_2cluster,vr56_dbscore_km_3cluster,vr56_dbscore_km_4cluster,vr56_dbscore_km_5cluster,vr56_dbscore_km_6cluster]
vr56_dbscores
# Out:
# [0.3637949991082315,
#  0.4397159509792017,
#  0.5128106631946328,
#  0.5195545871892511,
#  0.5256994697875269]

# %% [markdown]
# ### DB Scores:
#
# - Clustering Quality:
#   - The DB Scores confirm that K=2 provides the best clustering, with the most compact and distinct clusters.
#   - While K=3 has a slightly higher DB Score (0.43), it could still be considered if more segmentation is needed.
# - Decreasing Cluster Quality for Higher K:
#
#   - For K=4, K=5, and K=6, the DB Scores remain above 0.5, indicating that the clusters become less distinct and more dispersed.
#   - This suggests that increasing the number of clusters beyond K=3 results in diminishing returns.

# %% [markdown]
# ## DBSCAN

# %%
# Display valid results sorted by silhouette score
if "silhouette_score" in vr56_dbscan_results.columns:
    print(vr56_dbscan_results.sort_values(by="silhouette_score", ascending=False).head(10))
else:
    print("No valid clusters with silhouette_score were generated.")
# Out:
# No valid clusters with silhouette_score were generated.

# %%
from sklearn.metrics import silhouette_score as sscore
from sklearn.metrics import davies_bouldin_score as dbscore

# Calculate and print sscore and dbscore for Birch clusters
print("BIRCH Clustering Scores:")
print()
for i in range(2, 7):
    birch_model = eval(f"vr56_birch{i}")
    birch_labels = eval(f"vr56_birch{i}_labels")
    try:
        s = sscore(vr56_processed, birch_labels)
        db = dbscore(vr56_processed, birch_labels)
        print(f"n_clusters={i}: Silhouette Score = {s:.4f}, Davies-Bouldin Score = {db:.4f}")
        print()
    except ValueError:
        print(f"n_clusters={i}: Could not compute scores (likely only one cluster)")
# Out:
# BIRCH Clustering Scores:
#
# n_clusters=2: Silhouette Score = 0.1690, Davies-Bouldin Score = 2.0912
#
# n_clusters=3: Silhouette Score = 0.1413, Davies-Bouldin Score = 1.7898
#
# n_clusters=4: Silhouette Score = 0.1292, Davies-Bouldin Score = 1.8834
#
# n_clusters=5: Silhouette Score = 0.1294, Davies-Bouldin Score = 1.7753
#
# n_clusters=6: Silhouette Score = 0.1160, Davies-Bouldin Score = 1.5404

# %% [markdown]
# ## Model Run Statistics

# %% [markdown]
# ### Time Taken

# %%
import time

def time_model_run(model, data):
    start_time = time.time()
    model.fit(data)  # or model.fit_predict(data) depending on the model
    end_time = time.time()
    return end_time - start_time


# Example usage for KMeans (adapt for other models):
from sklearn.cluster import KMeans
kmeans_model = KMeans(n_clusters=2, init='random', random_state=43) #Example
kmeans_time = time_model_run(kmeans_model, vr56_ds_subset)
print(f"KMeans runtime: {kmeans_time:.4f} seconds")

# Example usage for DBSCAN
from sklearn.cluster import DBSCAN
dbscan_model = DBSCAN(eps=0.5, min_samples=5) #Example
dbscan_time = time_model_run(dbscan_model, vr56_processed)
print(f"DBSCAN runtime: {dbscan_time:.4f} seconds")

#Example usage for Birch
from sklearn.cluster import Birch
birch_model = Birch(n_clusters=2) #Example
birch_time = time_model_run(birch_model, vr56_processed)
print(f"Birch runtime: {birch_time:.4f} seconds")
# Out:
# KMeans runtime: 0.0295 seconds
# DBSCAN runtime: 0.1177 seconds
# Birch runtime: 1.6566 seconds

# %% [markdown]
# ### Memory Utilised

# %%
import tracemalloc

def get_model_memory_usage(model, data):
    tracemalloc.start()
    model.fit(data)  # or model.fit_predict(data) depending on the model
    current, peak = tracemalloc.get_traced_memory()
    tracemalloc.stop()
    return peak / (1024 * 1024)  # Convert bytes to MB


# Example usage for KMeans
kmeans_model = KMeans(n_clusters=2, init='random', random_state=43)
kmeans_memory = get_model_memory_usage(kmeans_model, vr56_ds_subset)
print(f"KMeans memory usage: {kmeans_memory:.2f} MB")

# Example usage for DBSCAN
dbscan_model = DBSCAN(eps=0.5, min_samples=5)
dbscan_memory = get_model_memory_usage(dbscan_model, vr56_processed)
print(f"DBSCAN memory usage: {dbscan_memory:.2f} MB")

# Example usage for Birch
birch_model = Birch(n_clusters=2)
birch_memory = get_model_memory_usage(birch_model, vr56_processed)
print(f"Birch memory usage: {birch_memory:.2f} MB")
# Out:
# KMeans memory usage: 0.33 MB
# DBSCAN memory usage: 2.44 MB
# Birch memory usage: 196.33 MB

# %% [markdown]
# --- End of Project ---
